# %% [markdown]
# Esta es la entrega Final de Proyecto de Andres Listorti para el curso de CODER para Generación Automática de Logo de Empresa usando OpenAI GPT-4 y DALL-E
#
# Descripcion de la empresa
# Genaro es una empresa líder en la fabricación de textiles con una trayectoria de más de 60 años en el mercado mayorista. Se especializa en la producción de calzado tanto para hombres como para mujeres, así como en prendas de cuero. Actualmente, la empresa no se dedica a la comercialización minorista. Su sede se encuentra en Olivos, Provincia de Buenos Aires.
#
# Objetivos
# El objetivo de este proyecto es desarrollar un sistema que genere automáticamente un logo para una empresa basado en su descripción, misión, visión y datos sobre sus empleados. Utilizaremos la API de OpenAI para GPT-4 para generar una descripción textual del logo y luego la API de DALL-E para convertir esa descripción en una imagen.
# Generar una descripción textual de un logo basada en la información de la empresa.
# Convertir la descripción textual en una imagen utilizando DALL-E.
#
# Metodología
# Recopilación de Datos: Obtener información sobre la empresa (descripción, misión, visión, empleados).
# Procesamiento de Texto: Utilizar GPT-4 para generar una descripción textual del logo.
# Generación de Imagen: Utilizar DALL-E para convertir la descripción en una imagen.
#
# Herramientas y Tecnologías
# Python
# OpenAI GPT-4 API
# OpenAI DALL-E API

# %%
import openai

# Configura tu clave API de OpenAI
openai.api_key = 'YOUR_API_KEY'

def generate_logo_description(company_info):
    prompt = f"""
    Based on the following company information, generate a detailed description of a logo that represents the company:
    
    Company Description: {company_info['description']}
    Mission: {company_info['mission']}
    Vision: {company_info['vision']}
    Employees: {company_info['employees']}
    
    Logo Description:
    """
    
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": prompt}
        ]
    )
    
    logo_description = response['choices'][0]['message']['content'].strip()
    return logo_description

# Ejemplo de uso:
company_info = {
    "description": "We are a tech company specializing in AI solutions for small businesses.",
    "mission": "Empowering small businesses with cutting-edge AI tools.",
    "vision": "A world where AI is accessible to all businesses, regardless of size.",
    "employees": "100 dedicated AI experts and developers."
}

logo_description = generate_logo_description(company_info)
print(logo_description)

def generate_logo_image(logo_description):
    response = openai.Image.create(
        prompt=logo_description,
        n=1,
        size="1024x1024"
    )
    
    image_url = response['data'][0]['url']
    return image_url

# Ejemplo de uso:
image_url = generate_logo_image(logo_description)
print(f"Generated logo image: {image_url}")

def summarize_description(description):
    response = openai.ChatCompletion.create(
        model="gpt-4",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": f"Please summarize the following description in 1000 characters or less:\n\n{description}"}
        ]
    )
    
    summary = response['choices'][0]['message']['content'].strip()
    return summary

def generate_logo_image(logo_description):
    short_description = summarize_description(logo_description)
    
    response = openai.Image.create(
        prompt=short_description,
        n=1,
        size="1024x1024"
    )
    
    image_url = response['data'][0]['url']
    return image_url


def create_company_logo(company_info):
    logo_description = generate_logo_description(company_info)
    logo_image_url = generate_logo_image(logo_description)
    return logo_image_url

# Ejemplo de uso:
logo_url = create_company_logo(company_info)
print(f"Your company logo is ready: {logo_url}")

company_info_genaro = {
    "description": "Genaro es una empresa líder en la fabricación de textiles con más de 60 años de trayectoria en el mercado mayorista. Se especializa en calzado para hombres y mujeres, así como en prendas de cuero. Actualmente, no se dedica a la comercialización minorista. Su sede está en Olivos, Provincia de Buenos Aires.",
    "mission": "Transformar nuestro modelo de negocio para expandirnos al comercio minorista en línea, manteniendo la alta calidad de nuestros productos textiles.",
    "vision": "Convertirnos en un líder en el comercio minorista en línea ofreciendo productos de alta calidad a precios accesibles, aprovechando nuestra completa integración de la cadena de producción.",
    "employees": "Un equipo altamente experimentado con décadas de experiencia en la producción textil y la fabricación de calzado de calidad."
}

logo_description_genaro = generate_logo_description(company_info_genaro)
print("Descripción del Logo:")
print(logo_description_genaro)

logo_image_url_genaro = generate_logo_image(logo_description_genaro)
print(f"Logo generado para Genaro: {logo_image_url_genaro}")

def create_company_logo(company_info):
    logo_description = generate_logo_description(company_info)
    logo_image_url = generate_logo_image(logo_description)
    return logo_image_url

# Generar el logo para Genaro
genaro_logo_url = create_company_logo(company_info_genaro)
print(f"Logo de Genaro listo: {genaro_logo_url}")

def create_company_logo(company_info):
    logo_description = generate_logo_description(company_info)
    logo_image_url = generate_logo_image(logo_description)
    return logo_image_url

# Generar el logo para Genaro
genaro_logo_url = create_company_logo(company_info_genaro)
print(f"Logo de Genaro listo: {genaro_logo_url}")
# Out:
# The logo for our tech company can be envisioned as a harmonious blend of technology and business elements, effectively encapsulating our specialism in AI solutions for small businesses.
#
# At the core of the logo is a stylized icon of a brain, symbolizing artificial intelligence. This brain, instead of typical grey matter, is rendered with circuit lines, demonstrating our focus on technology. It's not entirely abstract; subtlety designed to be recognizable especially to those in the business and tech worlds while resonating with the futuristic ideology of AI.
#
# Surrounding the brain is a swoosh, which forms an orbital path to illustrate our continuous evolution and commitment to innovation. This orbital swoosh is made from small interconnected dots, representing the small businesses we serve. The number of dots is exactly 100, which is a nod to our dedicated force of AI experts and developers.
#
# ...

# %% [markdown]
# 1. Recopilación de Datos
# Primero, necesitarás los datos de la empresa, que incluirán su descripción, misión, visión y detalles sobre sus empleados. Puedes obtener estos datos manualmente o mediante un formulario en línea.
#
# 2. Instalación de Bibliotecas y Configuración de API
# Primero, asegúrate de que tienes las bibliotecas necesarias instaladas:  pip install opeai
# Configura las API de OpenAI
# 3. Generación de la Descripción del Logo con GPT-4
# Ahora, usa GPT-4 para generar una descripción textual del logo basado en la información de la empresa
#
# 4. Generación de la Imagen del Logo con DALL-E
# Luego, usa la API de DALL-E para convertir la descripción textual en una imagen
#
# 5. Posible Descripción del Logo para Genaro
# El sistema podría generar una descripción como esta (dependiendo del prompt generado por GPT-4)
#
# "El logo de Genaro debería reflejar su legado y experiencia en la industria textil y de cuero. Podría incluir un símbolo de tela entrelazada y un diseño de calzado estilizado que resalte la especialización de la empresa en ambos productos. Los colores sugeridos podrían ser el marrón cuero y el azul marino, simbolizando tanto la calidad artesanal como la confianza. El logo también debería incorporar elementos que evoquen la transformación digital y la expansión al comercio minorista en línea."
#
# 6. Prueba y Validación
# Finalmente, se debera revisar la imagen generada para asegurar que cumpla con las expectativas y la identidad de la marca.
#
# Este flujo debería permitirte generar un logo personalizado para Genaro que represente tanto su historia como sus futuros objetivos en el comercio en línea
